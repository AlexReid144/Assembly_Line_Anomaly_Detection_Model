# %%
# pip install libraries
# !pip install simpy
# !pip install scikit-learn

# %%
# Import libraries
import pandas as pd
import numpy as np
import random as r
import math as m
import simpy
from sklearn import svm
from sklearn.model_selection import train_test_split

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data Synthesis
# %run '/content/drive/MyDrive/Data Mining Project/Notebooks/[Main] Data Synthesizer.ipynb'

# Data Preprocessing
# %run '/content/drive/MyDrive/Data Mining Project/Notebooks/[Main] Data Preprocessing.ipynb'

# Anomaly Detection Model
# %run '/content/drive/MyDrive/Data Mining Project/Notebooks/[Main] Anomaly Detection Model.ipynb'
# Out:
# Start Data Synthesis
# End Data Synthesis
# Start Data Preprocessing
#         Date  Value  Value_Lag_1  Value_Lag_2  Value_Lag_3
# 0 2023-01-01     10          NaN          NaN          NaN
# 1 2023-01-02     15         10.0          NaN          NaN
# 2 2023-01-03     20         15.0         10.0          NaN
# 3 2023-01-04     25         20.0         15.0         10.0
# 4 2023-01-05     30         25.0         20.0         15.0
# 5 2023-01-06     35         30.0         25.0         20.0
# 6 2023-01-07     40         35.0         30.0         25.0
# 7 2023-01-08     45         40.0         35.0         30.0
# 8 2023-01-09     50         45.0         40.0         35.0
# 9 2023-01-10     55         50.0         45.0         40.0
